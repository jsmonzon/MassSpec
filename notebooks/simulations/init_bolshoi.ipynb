# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.lines import Line2D
import warnings; warnings.simplefilter('ignore')
import sys
import h5py
import pandas as pd
import seaborn as sns
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_ancillary
import jsm_visualize
import jsm_simload
import jsm_mcmc
import jsm_stats
import jsm_models
import evolve as ev
import galhalo as gh
import profiles as profiles
import config as cfg

# %%
plt.style.use('../../../SatGen/notebooks/paper1/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches
levelz = [1-0.99, 1-0.95, 1-0.68]

# %% [markdown]
# ### first for bolshoi

# %%
cat = jsm_simload.HaloCatalogue(sim_title="bolshoi",
                                filepath="../../../misc/multidark/bolshoiP/N_AB_sub.dat",
                                mthresh=1.55e8*500,
                                xoff_thresh=0.07,
                                spin_thresh=0.07,
                                isolation_factor=3)
# Out:
# [bolshoi] mass threshold = 7.750e+10 Msun -> 500.0 particles (particle mass = 1.550e+08 Msun)
# Hosts: total=95737  after relaxation=72110 (75.3%)  after isolation=62066 (64.8%)

# %%
boltab = cat._build_host_table(sample="isolated")
boltab = boltab[boltab["logMvir"].between(12.5, 14.1, inclusive="neither")]
# boltab.to_csv("../../../misc/multidark/bolshoiP/BolshoiP_isolated_500.csv")

# %%
shmf = cat.compute_shmf(sample="relaxed")

# apply the same host mass cut as boltab, so the two stay aligned row-for-row
mass_mask = (shmf["logMvir"] > 12.5) & (shmf["logMvir"] < 14.1)

host_id       = shmf["host_id"][mass_mask]
logMvir       = shmf["logMvir"][mass_mask]
log10Mvir_sub = shmf["logMsub_all"][mass_mask]

np.savez(
    "../../data/summary_tabs/BolshoiP_500_shmf.npz",
    host_id=host_id,
    logMvir=logMvir,
    log10Mvir_sub=log10Mvir_sub,
)

# %%
boltab = cat._build_host_table(sample="relaxed")
boltab = boltab[boltab["logMvir"].between(12.5, 14.1, inclusive="neither")]
boltab.to_csv("../../../misc/multidark/bolshoiP/BolshoiP_relaxed_500.csv")

# %%
boltab = cat._build_host_table(sample="all")
boltab = boltab[boltab["logMvir"].between(12.5, 14.1, inclusive="neither")]
boltab.to_csv("../../../misc/multidark/bolshoiP/BolshoiP_all_500.csv")

# %%
cat = jsm_simload.HaloCatalogue(sim_title="bolshoi",
                                filepath="../../../misc/multidark/bolshoiP/N_AB_sub.dat",
                                mthresh=1.55e8*50,
                                xoff_thresh=0.07,
                                spin_thresh=0.07,
                                isolation_factor=3)

# %%
boltab = cat._build_host_table(sample="isolated")
boltab = boltab[boltab["logMvir"].between(12.5, 14.1, inclusive="neither")]
boltab.to_csv("../../../misc/multidark/bolshoiP/BolshoiP_isolated_50.csv")

# %%
cat = jsm_simload.HaloCatalogue(sim_title="bolshoi",
                                filepath="../../../misc/multidark/bolshoiP/N_AB_sub.dat",
                                mthresh=1.55e8*1000,
                                xoff_thresh=0.07,
                                spin_thresh=0.07,
                                isolation_factor=3)

# %%
boltab = cat._build_host_table(sample="isolated")
boltab = boltab[boltab["logMvir"].between(12.5, 14.1, inclusive="neither")]
boltab.to_csv("../../../misc/multidark/bolshoiP/BolshoiP_isolated_1000.csv")

# %% [markdown]
# ### now for vsmdpl

# %%
cat2 = jsm_simload.HaloCatalogue(sim_title="vsmdpl",
                                filepath="../../../misc/multidark/vsmdpl/N_AB_sub.dat",
                                mthresh=1.55e8*500,
                                xoff_thresh=0.07,
                                spin_thresh=0.07,
                                isolation_factor=3)
# Out:
# [vsmdpl] mass threshold = 7.750e+10 Msun -> 12500.0 particles (particle mass = 6.200e+06 Msun)
# Hosts: total=20359  after relaxation=15583 (76.5%)  after isolation=13064 (64.2%)

# %%
shmf = cat2.compute_shmf(sample="relaxed")

# apply the same host mass cut as boltab, so the two stay aligned row-for-row
mass_mask = (shmf["logMvir"] > 12.5) & (shmf["logMvir"] < 14.1)

host_id       = shmf["host_id"][mass_mask]
logMvir       = shmf["logMvir"][mass_mask]
log10Mvir_sub = shmf["logMsub_all"][mass_mask]

np.savez(
    "../../data/summary_tabs/VSMDPL_500_shmf.npz",
    host_id=host_id,
    logMvir=logMvir,
    log10Mvir_sub=log10Mvir_sub,
)

# %%
tab = cat2._build_host_table(sample="isolated")
tab = tab[tab["logMvir"].between(12.5, 14.1, inclusive="neither")]
tab.to_csv("../../../misc/multidark/vsmdpl/vsmdpl_isolated_500.csv")

# %%
boltab = cat2._build_host_table(sample="relaxed")
boltab = boltab[boltab["logMvir"].between(12.5, 14.1, inclusive="neither")]
boltab.to_csv("../../../misc/multidark/vsmdpl/vsmdpl_relaxed_500.csv")

# %%
boltab = cat2._build_host_table(sample="all")
boltab = boltab[boltab["logMvir"].between(12.5, 14.1, inclusive="neither")]
boltab.to_csv("../../../misc/multidark/vsmdpl/vsmdpl_all_500.csv")

# %%
cat2 = jsm_simload.HaloCatalogue(sim_title="vsmdpl",
                                filepath="../../../misc/multidark/vsmdpl/N_AB_sub.dat",
                                mthresh=1.55e8*50,
                                xoff_thresh=0.07,
                                spin_thresh=0.07,
                                isolation_factor=3)

# %%
tab = cat2._build_host_table(sample="isolated")
tab = tab[tab["logMvir"].between(12.5, 14.1, inclusive="neither")]
tab.to_csv("../../../misc/multidark/vsmdpl/vsmdpl_isolated_50.csv")

# %%
cat2 = jsm_simload.HaloCatalogue(sim_title="vsmdpl",
                                filepath="../../../misc/multidark/vsmdpl/N_AB_sub.dat",
                                mthresh=1.55e8*1000,
                                xoff_thresh=0.07,
                                spin_thresh=0.07,
                                isolation_factor=3)

# %%
tab = cat2._build_host_table(sample="isolated")
tab = tab[tab["logMvir"].between(12.5, 14.1, inclusive="neither")]
tab.to_csv("../../../misc/multidark/vsmdpl/vsmdpl_isolated_1000.csv")

# %%
# cat = jsm_simload.Bolshoi_HaloCatalogue(
#         "../../../misc/ForSebastian/full/N_AB_sub_BolPlanck.dat",
#         npart_thresh=500,
#         xoff_thresh=0.07,
#         spin_thresh=0.07,
#         isolation_factor=3)

# shmf = cat.compute_shmf(sample="relaxed")

# # apply the same host mass cut as boltab, so the two stay aligned row-for-row
# mass_mask = (shmf["logMvir"] > 12.5) & (shmf["logMvir"] < 14.1)

# host_id       = shmf["host_id"][mass_mask]
# logMvir       = shmf["logMvir"][mass_mask]
# log10Mvir_sub = shmf["log10Mvir_sub"][mass_mask]

# np.savez(
#     "../../data/sims/BolshoiP_500_shmf.npz",
#     host_id=host_id,
#     logMvir=logMvir,
#     log10Mvir_sub=log10Mvir_sub,
# )
