# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.lines import Line2D
import warnings; warnings.simplefilter('ignore')
import sys
import h5py
import pandas as pd
import seaborn as sns
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_ancillary
import jsm_visualize
import jsm_SHMR
import jsm_simload
import jsm_stats
import jsm_models
import evolve as ev
import galhalo as gh
import profiles as profiles
import config as cfg

# %%
plt.style.use('../../../SatGen/notebooks/paper1/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches
levelz = [1-0.99, 1-0.95, 1-0.68]

# %%
DF_tags = ["DF_1", "DF_2", "DF_3", "DF_4", "DF_5"]
beta_DF = np.array([1, 2, 3, 4, 5])*0.75

# %%
# DF_tags = ["DF_01", "DF_1", "DF_2", "DF_3", "DF_4", "DF_5", "DF_10"]
# beta_DF = np.array([0.1, 1, 2, 3, 4, 5, 10])*0.75

# %%
# DF_tags = ["DF_01", "DF_1", "DF_10"]
# beta_DF = np.array([0.1, 1, 10])*0.75

# %%
DF_list = []

for tag in DF_tags:
    temp = pd.read_csv("../../data/zhao/DF_test/"+tag+"/artificial_all.csv")
    temp_norm = jsm_simload.NormalizeData(temp, dataset_title="temp")
    # temp_norm.plot_poisson()

    DF_list.append(temp_norm)

# %%
boltab = pd.read_csv("../../../misc/multidark/bolshoiP/BolshoiP_all_500.csv")
bolnorm = jsm_simload.NormalizeData(boltab, dataset_title="BolshoiP")
# bolnorm.plot_poisson()

# %%
smmdpltab = pd.read_csv("../../../misc/multidark/vsmdpl/vsmdpl_all_500.csv")
smdnorm = jsm_simload.NormalizeData(smmdpltab, dataset_title="VSMDPL")
# smdnorm.plot_poisson()

# %%
# ------------------------------------------------------------------
# Discretized colormap for beta_DF, avoiding the light/dark extremes
# ------------------------------------------------------------------
n_bins = len(beta_DF)  # one discrete color per DF model

# sample only the middle portion of Blues_r so nothing gets too close to white
color_samples = cm.Blues(np.linspace(0.2, 0.7, n_bins))
cmap = mcolors.ListedColormap(color_samples)

# bin edges placed at the midpoints between consecutive (sorted) beta_DF values
beta_sorted = np.sort(beta_DF)
inner_edges = (beta_sorted[:-1] + beta_sorted[1:]) / 2
edges = np.concatenate([
    [beta_sorted[0] - (inner_edges[0] - beta_sorted[0])],
    inner_edges,
    [beta_sorted[-1] + (beta_sorted[-1] - inner_edges[-1])]
])

norm = mcolors.BoundaryNorm(edges, cmap.N)
colorz = [cmap(norm(b)) for b in beta_DF]

fig, axes = plt.subplots(
    4, 2,
    figsize=(double_textwidth, double_textwidth),
    sharex=True,
    constrained_layout=True
)

# ------------------------------------------------------------------
# Row 1, Col 0: <Nsub>
# ------------------------------------------------------------------
for data, color, label in zip(DF_list, colorz, beta_DF):
    axes[0, 0].plot(
        data.logMvir_bincenters,
        data.Nsub_mean,
        marker=".", lw=1, c=color
    )

axes[0, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.Nsub_mean,
    marker="*", lw=1, c="purple", label="BolshoiP"
)

axes[0, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.Nsub_mean,
    marker="*", lw=1, c="palevioletred", label="VSMDPL"
)

axes[0, 0].set_ylabel("< N$_{\\rm sub}$ >")
axes[0, 0].legend(fontsize=11, framealpha=1)
axes[0, 0].set_ylim(0)


# ------------------------------------------------------------------
# Row 1, Col 1: <fsub>
# ------------------------------------------------------------------
for data, color, label in zip(DF_list, colorz, beta_DF):
    axes[0, 1].plot(
        data.logMvir_bincenters,
        data.fsub_mean,
        marker=".", lw=1, c=color
    )

axes[0, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.fsub_mean,
    marker="*", lw=1, c="purple"
)

axes[0, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.fsub_mean,
    marker="*", lw=1, c="palevioletred"
)

axes[0, 1].set_ylabel("< f$_{\\rm sub}$ >")
# axes[0, 1].set_ylim(0)


# ------------------------------------------------------------------
# Row 2, Col 0: sigma(Nsub)
# ------------------------------------------------------------------
for data, color, label in zip(DF_list, colorz, beta_DF):
    axes[1, 0].plot(
        data.logMvir_bincenters,
        data.Nsub_std,
        marker=".", lw=1, c=color
    )

axes[1, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.Nsub_std,
    marker="*", lw=1, c="purple"
)

axes[1, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.Nsub_std,
    marker="*", lw=1, c="palevioletred"
)

axes[1, 0].set_ylabel("$\\sigma$ (N$_{\\rm sub}$) ")
axes[1, 0].set_ylim(0)

# ------------------------------------------------------------------
# Row 2, Col 1: sigma(fsub)
# ------------------------------------------------------------------
for data, color, label in zip(DF_list, colorz, beta_DF):
    axes[1, 1].plot(
        data.logMvir_bincenters,
        data.fsub_std,
        marker=".", lw=1, c=color
    )

axes[1, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.fsub_std,
    marker="*", lw=1, c="purple"
)

axes[1, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.fsub_std,
    marker="*", lw=1, c="palevioletred"
)

axes[1, 1].set_ylabel("$\\sigma$ (f$_{\\rm sub}$) ")
# axes[1, 1].set_ylim(0)


# ------------------------------------------------------------------
# Row 3, Col 0: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[2, 0].plot(
        data.logMvir_bincenters,
        data.rho_mat[0],
        marker=".", lw=1, c=color
    )

axes[2, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[0],
    marker="*", lw=1, c="purple"
)
axes[2, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[0],
    marker="*", lw=1, c="palevioletred"
)
axes[2, 0].set_ylim(-1, 0.1)
axes[2, 0].axhline(0, color="k", lw=0.8, ls="--")
axes[2, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")


# ------------------------------------------------------------------
# Row 3, Col 1: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[2, 1].plot(
        data.logMvir_bincenters,
        data.rho_mat[2],
        marker=".", lw=1, c=color
    )

axes[2, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[2],
    marker="*", lw=1, c="purple"
)
axes[2, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[2],
    marker="*", lw=1, c="palevioletred"
)

axes[2, 1].set_ylim(-1, 0.1)
axes[2, 1].axhline(0, color="k", lw=0.8, ls="--")
axes[2, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | z$_{50}$)")

# ------------------------------------------------------------------
# Row 4, Col 0: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[3, 0].plot(
        data.logMvir_bincenters,
        data.rho_mat[1],
        marker=".", lw=1, c=color
    )

axes[3, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[1],
    marker="*", lw=1, c="purple"
)
axes[3, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[1],
    marker="*", lw=1, c="palevioletred"
)

axes[3, 0].set_ylim(-1, 0.1)
axes[3, 0].axhline(0, color="k", lw=0.8, ls="--")
axes[3, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")

# ------------------------------------------------------------------
# Row 4, Col 1: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[3, 1].plot(
        data.logMvir_bincenters,
        data.rho_mat[3],
        marker=".", lw=1, c=color
    )

axes[3, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[3],
    marker="*", lw=1, c="purple"
)
axes[3, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[3],
    marker="*", lw=1, c="palevioletred"
)

axes[3, 1].set_ylim(-1, 0.1)
axes[3, 1].axhline(0, color="k", lw=0.8, ls="--")
axes[3, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | c$_{\\rm vir}$)")


# ------------------------------------------------------------------
# Common formatting
# ------------------------------------------------------------------

axes[3, 0].set_xlim(12.5, 14.1)
axes[3, 0].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[3, 0].set_xlabel(r"log M$_{\rm vir}$ [$\,h^{-1}$ M$_{\odot}$]")

axes[3, 1].set_xlim(12.5, 14.1)
axes[3, 1].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[3, 1].set_xlabel(r"log M$_{\rm vir}$ [$\,h^{-1}$ M$_{\odot}$]")

# ------------------------------------------------------------------
# Colorbar spanning both panels in row 1, discretized, ticks/label on top
# ------------------------------------------------------------------
sm = cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = fig.colorbar(
    sm, ax=axes[0, :], location="top",
    pad=0.08, aspect=60, shrink=1.0,
    ticks=beta_DF
)
cbar.ax.xaxis.set_ticks_position("top")
cbar.ax.xaxis.set_label_position("top")
cbar.set_label("SatGen | $\\beta_{\\rm DF}$")

axes[0,0].text(0.93, 0.1, s="A",  transform=axes[0, 0].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
axes[0,1].text(0.93, 0.1, s="B",  transform=axes[0, 1].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
axes[1,0].text(0.93, 0.1, s="C",  transform=axes[1, 0].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
axes[1,1].text(0.93, 0.1, s="D",  transform=axes[1, 1].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
axes[2,0].text(0.93, 0.1, s="E",  transform=axes[2, 0].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
axes[2,1].text(0.93, 0.1, s="F",  transform=axes[2, 1].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
axes[3,0].text(0.93, 0.1, s="G",  transform=axes[3, 0].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
axes[3,1].text(0.93, 0.1, s="H",  transform=axes[3, 1].transAxes, bbox=dict(boxstyle="round", facecolor="white"))
# plt.savefig("../../figures/DF_full.pdf", bbox_inches="tight")
plt.show()

# %%
# ------------------------------------------------------------------
# Colors for each beta_DF model
# ------------------------------------------------------------------
beta_colors = {
    beta_DF[0]: "lightskyblue",
    beta_DF[1]: "C0",
    beta_DF[2]: "darkblue",
}

colorz = [beta_colors[beta] for beta in beta_DF]


fig, axes = plt.subplots(
    4, 2,
    figsize=(double_textwidth, double_textwidth),
    sharex=True,
    constrained_layout=True
)

# ------------------------------------------------------------------
# Row 1, Col 0: <Nsub>
# ------------------------------------------------------------------
for data, color, beta in zip(DF_list, colorz, beta_DF):
    axes[0, 0].plot(
        data.logMvir_bincenters,
        data.Nsub_mean,
        marker=".", lw=1, c=color
    )

axes[0, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.Nsub_mean,
    marker="*", lw=1, c="purple", label="BolshoiP"
)

axes[0, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.Nsub_mean,
    marker="*", lw=1, c="palevioletred", label="VSMDPL"
)

axes[0, 0].set_ylabel("< N$_{\\rm sub}$ >")
axes[0, 0].legend(fontsize=10, framealpha=1)
axes[0, 0].set_ylim(0)


# ------------------------------------------------------------------
# Row 1, Col 1: <fsub>
# ------------------------------------------------------------------
for data, color, beta in zip(DF_list, colorz, beta_DF):
    axes[0, 1].plot(
        data.logMvir_bincenters,
        data.fsub_mean,
        marker=".", lw=1, c=color
    )

axes[0, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.fsub_mean,
    marker="*", lw=1, c="purple"
)

axes[0, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.fsub_mean,
    marker="*", lw=1, c="palevioletred"
)

axes[0, 1].set_ylabel("< f$_{\\rm sub}$ >")


# ------------------------------------------------------------------
# Row 2, Col 0: sigma(Nsub)
# ------------------------------------------------------------------
for data, color, beta in zip(DF_list, colorz, beta_DF):
    axes[1, 0].plot(
        data.logMvir_bincenters,
        data.Nsub_std,
        marker=".", lw=1, c=color
    )

axes[1, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.Nsub_std,
    marker="*", lw=1, c="purple"
)

axes[1, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.Nsub_std,
    marker="*", lw=1, c="palevioletred"
)

axes[1, 0].set_ylabel("$\\sigma$ (N$_{\\rm sub}$) ")
axes[1, 0].set_ylim(0)


# ------------------------------------------------------------------
# Row 2, Col 1: sigma(fsub)
# ------------------------------------------------------------------
for data, color, beta in zip(DF_list, colorz, beta_DF):
    axes[1, 1].plot(
        data.logMvir_bincenters,
        data.fsub_std,
        marker=".", lw=1, c=color
    )

axes[1, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.fsub_std,
    marker="*", lw=1, c="purple"
)

axes[1, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.fsub_std,
    marker="*", lw=1, c="palevioletred"
)

axes[1, 1].set_ylabel("$\\sigma$ (f$_{\\rm sub}$) ")


# ------------------------------------------------------------------
# Row 3, Col 0: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[2, 0].plot(
        data.logMvir_bincenters,
        data.rho_mat[0],
        marker=".", lw=1, c=color
    )

axes[2, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[0],
    marker="*", lw=1, c="purple"
)

axes[2, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[0],
    marker="*", lw=1, c="palevioletred"
)

axes[2, 0].set_ylim(-1, 0.1)
axes[2, 0].axhline(0, color="k", lw=0.8, ls="--")
axes[2, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")


# ------------------------------------------------------------------
# Row 3, Col 1: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[2, 1].plot(
        data.logMvir_bincenters,
        data.rho_mat[2],
        marker=".", lw=1, c=color
    )

axes[2, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[2],
    marker="*", lw=1, c="purple"
)

axes[2, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[2],
    marker="*", lw=1, c="palevioletred"
)

axes[2, 1].set_ylim(-1, 0.1)
axes[2, 1].axhline(0, color="k", lw=0.8, ls="--")
axes[2, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | z$_{50}$)")


# ------------------------------------------------------------------
# Row 4, Col 0: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[3, 0].plot(
        data.logMvir_bincenters,
        data.rho_mat[1],
        marker=".", lw=1, c=color
    )

axes[3, 0].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[1],
    marker="*", lw=1, c="purple"
)

axes[3, 0].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[1],
    marker="*", lw=1, c="palevioletred"
)

axes[3, 0].set_ylim(-1, 0.1)
axes[3, 0].axhline(0, color="k", lw=0.8, ls="--")
axes[3, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")


# ------------------------------------------------------------------
# Row 4, Col 1: rho
# ------------------------------------------------------------------
for data, color in zip(DF_list, colorz):
    axes[3, 1].plot(
        data.logMvir_bincenters,
        data.rho_mat[3],
        marker=".", lw=1, c=color
    )

axes[3, 1].plot(
    bolnorm.logMvir_bincenters,
    bolnorm.rho_mat[3],
    marker="*", lw=1, c="purple"
)

axes[3, 1].plot(
    smdnorm.logMvir_bincenters,
    smdnorm.rho_mat[3],
    marker="*", lw=1, c="palevioletred"
)

axes[3, 1].set_ylim(-1, 0.1)
axes[3, 1].axhline(0, color="k", lw=0.8, ls="--")
axes[3, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | c$_{\\rm vir}$)")


# ------------------------------------------------------------------
# Common formatting
# ------------------------------------------------------------------
axes[3, 0].set_xlim(12.5, 14.1)
axes[3, 0].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[3, 0].set_xlabel(r"log M$_{\rm vir}$ [$\,h^{-1}$ M$_{\odot}$]")

axes[3, 1].set_xlim(12.5, 14.1)
axes[3, 1].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[3, 1].set_xlabel(r"log M$_{\rm vir}$ [$\,h^{-1}$ M$_{\odot}$]")


# ------------------------------------------------------------------
# Legend for beta_DF in panel B
# ------------------------------------------------------------------
beta_handles = [
    plt.Line2D(
        [0], [0],
        marker=".",
        linestyle="-",
        lw=1,
        color=color,
        label=rf"$\beta_{{\rm DF}} = {beta:g}$"
    )
    for beta, color in zip(beta_DF, colorz)
]

axes[1, 0].legend(
    handles=beta_handles,
    fontsize=10,
    framealpha=1,
    loc="best"
)


# ------------------------------------------------------------------
# Panel labels
# ------------------------------------------------------------------
axes[0,0].text(
    0.93, 0.1, s="A", transform=axes[0,0].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)
axes[0,1].text(
    0.93, 0.1, s="B", transform=axes[0,1].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)
axes[1,0].text(
    0.93, 0.1, s="C", transform=axes[1,0].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)
axes[1,1].text(
    0.93, 0.1, s="D", transform=axes[1,1].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)
axes[2,0].text(
    0.93, 0.1, s="E", transform=axes[2,0].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)
axes[2,1].text(
    0.93, 0.1, s="F", transform=axes[2,1].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)
axes[3,0].text(
    0.93, 0.1, s="G", transform=axes[3,0].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)
axes[3,1].text(
    0.93, 0.1, s="H", transform=axes[3,1].transAxes,
    bbox=dict(boxstyle="round", facecolor="white")
)

plt.tight_layout()
# plt.savefig("../../figures/DF_full.pdf", bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 10
#       1 # ------------------------------------------------------------------
#       2 # Colors for each beta_DF model
#       3 # ------------------------------------------------------------------
#       4 beta_colors = {
#       5     beta_DF[0]: "lightskyblue",
#       6     beta_DF[1]: "C0",
#       7     beta_DF[2]: "darkblue",
#       8 }
# ---> 10 colorz = [beta_colors[beta] for beta in beta_DF]
#      13 fig, axes = plt.subplots(
#      14     4, 2,
#      15     figsize=(double_textwidth, double_textwidth),
#      16     sharex=True,
#      17     constrained_layout=True
#      18 )
#      20 # ------------------------------------------------------------------
#      21 # Row 1, Col 0: <Nsub>
#      22 # ------------------------------------------------------------------
#
# ...
