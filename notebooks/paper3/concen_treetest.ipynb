# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.lines import Line2D
import matplotlib as mpl
import warnings; warnings.simplefilter('ignore')
import os
import sys
import h5py
import pandas as pd
import seaborn as sns
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_ancillary
import jsm_stellarhalo
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_simload
import evolve as ev
import galhalo as gh
import profiles as profiles
import config as cfg

# %%
rng = np.random.default_rng(13)

# %%
test140 = jsm_stellarhalo.Tree_Reader(file="../../data/local_trees/evolved_trees/tree_14.0.npz", mass_threshold=1e9, verbose=True)
# Out:
# reading in the tree!
# converting cyldrical coordinates to cartesian!
# counting subhalos in different regimes
# saving the subhalo mass function

# %%
test140.compute_concentration(Nparticles=int(1e6), rng=np.random.default_rng(13), c_true=11)
# Out:
# The total number of surviving (k=1) subhalos: 537
# The TRUE value of concentration: 11.000
# The total fraction of mass in surviving (k=1) subhalos: 0.112
# the concentration with no substructure and a well defined center of mass: 11.029
# the concentration with substructure and the same center of mass as before: 8.414
# the concentration with substructure and with a new center of mass: 8.400

# %%
test = test140.write_out_concentrations()

# %%
test["c_measured_fixed_COM"]
# Out:
# array([7.75504902e+00, 3.29490152e-02, 2.73803154e+02, 2.88456610e-02])

# %%
test.keys()
# Out:
# dict_keys(['tree_index', 'MAH', 'host_Rvir', 'host_c', 'host_Rmax', 'host_Vcirc', 'host_z10', 'host_z50', 'host_z90', 'Nsub_tot', 'c_measured_smooth', 'c_measured_fixed_COM', 'c_measured_shifted_COM'])

# %%
test["Nsub_tot"]
# Out:
# 15700

# %%
S0 = jsm_ancillary.load_sample("../../../StellarHalo/data/fiducial/S0_sample.h5")
