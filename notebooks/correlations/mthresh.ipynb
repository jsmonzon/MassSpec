# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.lines import Line2D
import warnings; warnings.simplefilter('ignore')
import sys
import h5py
import pandas as pd
import seaborn as sns
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_ancillary
import jsm_visualize
import jsm_simload
import jsm_mcmc
import jsm_stats
import jsm_models
import evolve as ev
import galhalo as gh
import profiles as profiles
import config as cfg
import matplotlib.ticker as ticker

# %%
plt.style.use('../../../SatGen/notebooks/paper1/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches
levelz = [1-0.99, 1-0.95, 1-0.68]

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/zhao/N50/", "artificial")
# test.to_csv("../../data/zhao/N50/summary_tabs/artificial_all.csv")

# %%
art_1000 = pd.read_csv("../../data/zhao/N1000/summary_tabs/artificial_all.csv")
art_500 = pd.read_csv("../../data/zhao/N500/summary_tabs/artificial_all.csv")
art_50 = pd.read_csv("../../data/zhao/N50/summary_tabs/artificial_all.csv")

sat1000 = jsm_simload.NormalizeData(art_1000, dataset_title="500")
sat500 = jsm_simload.NormalizeData(art_500, dataset_title="500")
sat50 = jsm_simload.NormalizeData(art_50, dataset_title="50")

# %%
fig, axes = plt.subplots(2, 2, figsize=(double_textwidth, double_textwidth), sharex=True, sharey=True)

datasets = [sat50, sat500, sat1000]
colors = ["C1", "C0", "C2"]
labelz = ["$7.75 \\times 10^9$", "$7.75 \\times 10^{10}$", "$1.55 \\times 10^{11}$"]

for j, dataset in enumerate(datasets):
    axes[0, 0].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[0],
                        yerr=dataset.rho_err_mat[0], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[1, 0].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[1],
                        yerr=dataset.rho_err_mat[1], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[0, 1].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[2],
                        yerr=dataset.rho_err_mat[2], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[1, 1].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[3],
                        yerr=dataset.rho_err_mat[3], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])

for ax in axes.flatten():
    ax.axhline(0, color="k", lw=0.8, ls="--")

axes[0, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")
axes[1, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")
axes[0, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | z$_{50}$)")
axes[1, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | c$_{\\rm vir}$)")

axes[1, 1].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[1, 0].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_ylim(-1, 1)

# Average rho_S across mass bins
avg_sat = np.average(sat50.rho_mat, axis=1)
avg_bol = np.average(sat500.rho_mat, axis=1)
avg_smd = np.average(sat1000.rho_mat, axis=1)

panel_indices = [
    (axes[0, 0], 0),
    (axes[1, 0], 1),
    (axes[0, 1], 2),
    (axes[1, 1], 3)
]

for ax, i in panel_indices:
    avgs = [avg_sat[i], avg_bol[i], avg_smd[i]]

    for k, (avg, color) in enumerate(zip(avgs, colors)):
        ax.text(
            0.05,
            0.90 - k * 0.065,
            rf"$\langle\rho_S\rangle = {avg:.2f}$",
            transform=ax.transAxes,
            color=color,
            fontsize=11
        )

# Panel labels
axes[0, 0].text(0.9, 0.9, "A", transform=axes[0, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[0, 1].text(0.9, 0.9, "B", transform=axes[0, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 0].text(0.9, 0.9, "C", transform=axes[1, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 1].text(0.9, 0.9, "D", transform=axes[1, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))

# Figure-level legend spanning the top, single row, with a title precursor
handles, labels_ = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels_, loc="lower center", bbox_to_anchor=(0.55, 0.92), fontsize=11,
           ncol=len(labelz), framealpha=1, frameon=True, bbox_transform=fig.transFigure,
           title="SatGen (vdb) | m$_{\\rm thresh}\\ [h^{-1}\\ M_\\odot]:$", title_fontsize=11)

plt.tight_layout(rect=[0, 0, 1, 0.94])
# plt.savefig("../../figures/corr_comp.pdf", bbox_inches="tight")
plt.show()

# %%
bol1000 = pd.read_csv("../../data/summary_tabs/BolshoiP/BolshoiP_all_1000.csv")
bol500 = pd.read_csv("../../data/summary_tabs/BolshoiP/BolshoiP_all_500.csv")
bol50 = pd.read_csv("../../data/summary_tabs/BolshoiP/BolshoiP_all_50.csv")

norm1000 = jsm_simload.NormalizeData(bol1000, dataset_title="500")
norm500 = jsm_simload.NormalizeData(bol500, dataset_title="500")
norm50 = jsm_simload.NormalizeData(bol50, dataset_title="50")

# %%
fig, axes = plt.subplots(2, 2, figsize=(double_textwidth, double_textwidth), sharex=True, sharey=True)

datasets = [norm50, norm500, norm1000]
colors = ["C1", "purple", "C2"]
labelz = ["$7.75 \\times 10^9$", "$7.75 \\times 10^{10}$", "$1.55 \\times 10^{11}$"]

for j, dataset in enumerate(datasets):
    axes[0, 0].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[0],
                        yerr=dataset.rho_err_mat[0], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[1, 0].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[1],
                        yerr=dataset.rho_err_mat[1], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[0, 1].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[2],
                        yerr=dataset.rho_err_mat[2], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[1, 1].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[3],
                        yerr=dataset.rho_err_mat[3], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])

for ax in axes.flatten():
    ax.axhline(0, color="k", lw=0.8, ls="--")

axes[0, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")
axes[1, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")
axes[0, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | z$_{50}$)")
axes[1, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | c$_{\\rm vir}$)")

axes[1, 1].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[1, 0].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_ylim(-1, 1)

# Average rho_S across mass bins
avg_sat = np.average(norm50.rho_mat, axis=1)
avg_bol = np.average(norm500.rho_mat, axis=1)
avg_smd = np.average(norm1000.rho_mat, axis=1)

panel_indices = [
    (axes[0, 0], 0),
    (axes[1, 0], 1),
    (axes[0, 1], 2),
    (axes[1, 1], 3)
]

for ax, i in panel_indices:
    avgs = [avg_sat[i], avg_bol[i], avg_smd[i]]

    for k, (avg, color) in enumerate(zip(avgs, colors)):
        ax.text(
            0.05,
            0.90 - k * 0.065,
            rf"$\langle\rho_S\rangle = {avg:.2f}$",
            transform=ax.transAxes,
            color=color,
            fontsize=11
        )

# Panel labels
axes[0, 0].text(0.9, 0.9, "A", transform=axes[0, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[0, 1].text(0.9, 0.9, "B", transform=axes[0, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 0].text(0.9, 0.9, "C", transform=axes[1, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 1].text(0.9, 0.9, "D", transform=axes[1, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))

# Figure-level legend spanning the top, single row, with a title precursor
handles, labels_ = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels_, loc="lower center", bbox_to_anchor=(0.55, 0.92), fontsize=11,
           ncol=len(labelz), framealpha=1, frameon=True, bbox_transform=fig.transFigure,
           title="BolshoiP | m$_{\\rm thresh}\\ [h^{-1}\\ M_\\odot]:$", title_fontsize=11)

plt.tight_layout(rect=[0, 0, 1, 0.94])
# plt.savefig("../../figures/corr_comp.pdf", bbox_inches="tight")
plt.show()

# %%
v1000 = pd.read_csv("../../data/summary_tabs/VSMDPL/vsmdpl_all_1000.csv")
v500 = pd.read_csv("../../data/summary_tabs/VSMDPL/vsmdpl_all_500.csv")
v50 = pd.read_csv("../../data/summary_tabs/VSMDPL/vsmdpl_all_50.csv")

vsm1000 = jsm_simload.NormalizeData(v1000, dataset_title="500")
vsm500 = jsm_simload.NormalizeData(v500, dataset_title="500")
vsm50 = jsm_simload.NormalizeData(v50, dataset_title="50")

# %%
fig, axes = plt.subplots(2, 2, figsize=(double_textwidth, double_textwidth), sharex=True, sharey=True)

datasets = [vsm50, vsm500, vsm1000]
colors = ["C1", "palevioletred", "C2"]
labelz = ["$7.75 \\times 10^9$", "$7.75 \\times 10^{10}$", "$1.55 \\times 10^{11}$"]

for j, dataset in enumerate(datasets):
    axes[0, 0].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[0],
                        yerr=dataset.rho_err_mat[0], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[1, 0].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[1],
                        yerr=dataset.rho_err_mat[1], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[0, 1].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[2],
                        yerr=dataset.rho_err_mat[2], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])
    axes[1, 1].errorbar(dataset.logMvir_bincenters, dataset.rho_mat[3],
                        yerr=dataset.rho_err_mat[3], color=colors[j],
                        capsize=3, lw=1, label=labelz[j])

for ax in axes.flatten():
    ax.axhline(0, color="k", lw=0.8, ls="--")

axes[0, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")
axes[1, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")
axes[0, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | z$_{50}$)")
axes[1, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | c$_{\\rm vir}$)")

axes[1, 1].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[1, 0].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_ylim(-1, 1)

# Average rho_S across mass bins
avg_sat = np.average(vsm50.rho_mat, axis=1)
avg_bol = np.average(vsm500.rho_mat, axis=1)
avg_smd = np.average(vsm1000.rho_mat, axis=1)

panel_indices = [
    (axes[0, 0], 0),
    (axes[1, 0], 1),
    (axes[0, 1], 2),
    (axes[1, 1], 3)
]

for ax, i in panel_indices:
    avgs = [avg_sat[i], avg_bol[i], avg_smd[i]]

    for k, (avg, color) in enumerate(zip(avgs, colors)):
        ax.text(
            0.05,
            0.90 - k * 0.065,
            rf"$\langle\rho_S\rangle = {avg:.2f}$",
            transform=ax.transAxes,
            color=color,
            fontsize=11
        )

# Panel labels
axes[0, 0].text(0.9, 0.9, "A", transform=axes[0, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[0, 1].text(0.9, 0.9, "B", transform=axes[0, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 0].text(0.9, 0.9, "C", transform=axes[1, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 1].text(0.9, 0.9, "D", transform=axes[1, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))

# Figure-level legend spanning the top, single row, with a title precursor
handles, labels_ = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels_, loc="lower center", bbox_to_anchor=(0.55, 0.92), fontsize=11,
           ncol=len(labelz), framealpha=1, frameon=True, bbox_transform=fig.transFigure,
           title="VSMPDL | m$_{\\rm thresh}\\ [h^{-1}\\ M_\\odot]:$", title_fontsize=11)

plt.tight_layout(rect=[0, 0, 1, 0.94])
# plt.savefig("../../figures/corr_comp.pdf", bbox_inches="tight")
plt.show()

# %% [markdown]
# full panel

# %%
from matplotlib.lines import Line2D

fig, axes = plt.subplots(2, 2, figsize=(double_textwidth, single_textwidth*1.5), sharex=True, sharey=True)

datasets = [vsm1000, vsm500, vsm50]
color1 = "palevioletred"
linestyles = [":", "--", "-"]
labelz = ["$7.75 \\times 10^9$", "$7.75 \\times 10^{10}$", "$1.55 \\times 10^{11}$"]

for j, dataset in enumerate(datasets):
    marker = "*" if j == 2 else None
    axes[0, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[0],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[1, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[1],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[0, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[2],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[1, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[3],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)

datasets = [norm1000, norm500, norm50]
color1 = "purple"

for j, dataset in enumerate(datasets):
    marker = "*" if j == 2 else None
    axes[0, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[0],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[1, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[1],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[0, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[2],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[1, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[3],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)


datasets = [sat1000, sat500, sat50]
color1 = "C0"

for j, dataset in enumerate(datasets):
    marker = "." if j == 2 else None
    axes[0, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[0],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[1, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[1],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[0, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[2],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)
    axes[1, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[3],
                    ls=linestyles[j], lw=1, marker=marker, label=labelz[j], color=color1)

for ax in axes.flatten():
    ax.axhline(0, color="k", lw=0.8, ls="--")

axes[0, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")
axes[1, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")
axes[0, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | z$_{50}$)")
axes[1, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | c$_{\\rm vir}$)")

axes[1, 1].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[1, 0].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_ylim(-1, 1)

# Panel labels
axes[0, 0].text(0.9, 0.9, "A", transform=axes[0, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[0, 1].text(0.9, 0.9, "B", transform=axes[0, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 0].text(0.9, 0.9, "C", transform=axes[1, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 1].text(0.9, 0.9, "D", transform=axes[1, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))

# --- Linestyle key (black), placed inside panel A ---
linestyle_markers = [None, None, "."]
linestyle_handles = [Line2D([0], [0], color="k", ls=ls, lw=1, marker=m)
                      for ls, m in zip(linestyles, linestyle_markers)]
labelz = ["$1.55 \\times 10^{11}\ [h^{-1}\\ M_\\odot]$", "$7.75 \\times 10^{10}\ [h^{-1}\\ M_\\odot]$", "$7.75 \\times 10^9\ [h^{-1}\\ M_\\odot]$"]
axes[0, 0].legend(linestyle_handles, labelz, loc=2,
                   fontsize=11, frameon=True, framealpha=1, handlelength=2)

# --- Top figure-level legend: solid line per model, in its color ---
model_colors = ["C0", "purple", "palevioletred"]  # SatGen, BolshoiP, VSMDPL
model_labels = ["SatGen", "BolshoiP", "VSMDPL"]

handle0 = Line2D([0], [0], color=model_colors[0], ls="-", lw=1.5, marker=".") 
handle1 = Line2D([0], [0], color=model_colors[1], ls="-", lw=1.5, marker="*")
handle2 = Line2D([0], [0], color=model_colors[2], ls="-", lw=1.5, marker="*")

axes[0, 1].legend([handle0, handle1, handle2], model_labels, loc=2)

# fig.legend([handle0, handle1, handle2], model_labels, loc="lower center", bbox_to_anchor=(0.5, 0.92),
#            ncol=len(model_labels), framealpha=1, frameon=True, bbox_transform=fig.transFigure)

plt.tight_layout()
plt.savefig("../../figures/mass_thresfull.pdf", bbox_inches="tight")
plt.show()

# %%
mass_rat126 = [
    1.55e11 / 10**12.6,
    7.75e10 / 10**12.6,
    7.75e9 / 10**12.6
]

mass_rat140 = [
    1.55e11 / 1e14,
    7.75e10 / 1e14,
    7.75e9 / 1e14
]

datasets = [sat1000, sat500, sat50]

labelz = ["A", "B", "C", "D"]

# %%
for j in range(4):

    y126 = [val.rho_mat[j, 0] for val in datasets]
    y140 = [val.rho_mat[j, 7] for val in datasets]

    plt.plot(mass_rat126, y126, color=f"C{j}", marker="v", label=labelz[j])
    plt.plot(mass_rat140, y140, color=f"C{j}", marker="^")

plt.xscale("log")
plt.legend()

plt.ylim(-1, 0)
plt.xlabel("mthresh / Mvir")
plt.axvline(0.5, ls=":", color="k")
plt.axvline(0.1, ls=":", color="k")
