# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.lines import Line2D
import warnings; warnings.simplefilter('ignore')
import sys
import h5py
import pandas as pd
import seaborn as sns
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_ancillary
import jsm_visualize
import jsm_simload
import jsm_mcmc
import jsm_stats
import jsm_models
import evolve as ev
import galhalo as gh
import profiles as profiles
import config as cfg
import matplotlib.ticker as ticker

# %%
plt.style.use('../../../SatGen/notebooks/paper1/paper.mplstyle')
double_textwidth = 7.0 #inches
single_textwidth = 3.5 #inches
levelz = [1-0.99, 1-0.95, 1-0.68]

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/vdb/N50/", "artificial")
# test.to_csv("../../data/vdb/N50/summary_tabs/artificial_all.csv")

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/vdb/N500/", "artificial")
# test.to_csv("../../data/vdb/N500/summary_tabs/artificial_all.csv")

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/vdb/N1000/", "artificial")
# test.to_csv("../../data/vdb/N1000/summary_tabs/artificial_all.csv")

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/vdb/N500/", "rvir_surv")
# test.to_csv("../../data/vdb/N500/summary_tabs/rvir_surv_all.csv")

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/vdb/N500/", "surviving")
# test.to_csv("../../data/vdb/N500/summary_tabs/surviving_all.csv")

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/vdb/500_particles/", "artificial", order="k2")
# test.to_csv("../../data/vdb/500_particles/summary_tabs/artificial_k2.csv")

# %%
# test = jsm_ancillary.load_massspec_z0("../../data/vdb/500_particles/", "artificial", order="k3")
# test.to_csv("../../data/vdb/500_particles/summary_tabs/artificial_k3.csv")

# %%
satgen500 = pd.read_csv("../../data/zhao/DF_test/DF_1/artificial_all.csv")
# rvir = pd.read_csv("../../data/zhao/N500/summary_tabs/rvir_surv_all.csv")
# surv = pd.read_csv("../../data/zhao/N500/summary_tabs/surviving_all.csv")

# %%
artnorm = jsm_simload.NormalizeData(satgen500, dataset_title="resilient")
# rvirnorm = jsm_simload.NormalizeData(rvir, dataset_title="within R$_{\\rm vir}$")
# survnorm = jsm_simload.NormalizeData(surv, dataset_title="surviving")

# %%
fig, axes = plt.subplots(3, 1, figsize=(single_textwidth, double_textwidth), sharex=True, sharey=True)

datasets = [artnorm, artnorm, artnorm]
colors = ["C0", "C1", "C2", "C3"]
labelz = ["artificial disruption", "within R$_{\\rm vir}$", "surviving"]

for j, dataset in enumerate(datasets):
    for i in range(3):
        axes[i].errorbar(
            dataset.logMvir_bincenters, dataset.rho_mat[i], yerr=dataset.rho_err_mat[i], color=colors[j], capsize=3, lw=1, label=labelz[j])

axes[0].set_ylim(-1, 1)
axes[0].axhline(0, color="k", lw=0.8, ls="--")
axes[1].axhline(0, color="k", lw=0.8, ls="--")
axes[2].axhline(0, color="k", lw=0.8, ls="--")
axes[2].set_xlabel("log M$_{\\rm vir}\ [h^{-1}\ M_\odot]$")

axes[0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")
axes[1].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")
axes[2].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | m$_{\\rm sub}^{\\rm max}$)")

axes[2].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[2].legend(framealpha=1, loc=3)
plt.tight_layout()
# plt.savefig("../../figures/rho_suborder.pdf", bbox_inches="tight")
plt.show()

# %%
boltab = pd.read_csv("../../data/summary_tabs/BolshoiP/BolshoiP_all_500.csv")
bolnorm = jsm_simload.NormalizeData(boltab, dataset_title="BolshoiP")

boltab_rel = pd.read_csv("../../data/summary_tabs/BolshoiP/BolshoiP_isolated_500.csv")
bolnorm_rel = jsm_simload.NormalizeData(boltab_rel, dataset_title="BolshoiP_relaxed")

# %%
smdtab = pd.read_csv("../../data/summary_tabs/VSMDPL/VSMDPL_all_500.csv")
smdnorm = jsm_simload.NormalizeData(smdtab, dataset_title="VSMDPL")

smdtab_rel = pd.read_csv("../../data/summary_tabs/VSMDPL/VSMDPL_isolated_500.csv")
smdnorm_rel = jsm_simload.NormalizeData(smdtab_rel, dataset_title="VSMDPL_relaxed")

# %%
fig, axes = plt.subplots(2, 2, figsize=(double_textwidth, single_textwidth*1.5), sharex=True, sharey=True)

datasets = [artnorm, bolnorm_rel, smdnorm_rel, bolnorm, smdnorm]
colors = ["C0", "purple", "palevioletred", "purple", "palevioletred"]
labels = ["SatGen", "BolshoiP", "VSMDPL", "VSMDPL", "VSMDPL"]
linestyles = ["-", "-", "-", ":", ":"]
markers = [".", "*", "*", None, None]


for j, dataset in enumerate(datasets):
    axes[0, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[0],
                        ls=linestyles[j], color=colors[j],  lw=1, label=labels[j], marker=markers[j])
    axes[1, 0].plot(dataset.logMvir_bincenters, dataset.rho_mat[1],
                        ls=linestyles[j], color=colors[j],  lw=1, label=labels[j], marker=markers[j])
    axes[0, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[2],
                        ls=linestyles[j], color=colors[j],  lw=1, label=labels[j], marker=markers[j])
    axes[1, 1].plot(dataset.logMvir_bincenters, dataset.rho_mat[3],
                        ls=linestyles[j], color=colors[j],  lw=1, label=labels[j], marker=markers[j])

for ax in axes.flatten():
    ax.axhline(0, color="k", lw=0.8, ls="--")

axes[0, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | z$_{50}$)")
axes[1, 0].set_ylabel("$\\rho_S$ (N$_{\\rm sub}$ | c$_{\\rm vir}$)")
axes[0, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | z$_{50}$)")
axes[1, 1].set_ylabel("$\\rho_S$ (f$_{\\rm sub}$ | c$_{\\rm vir}$)")

axes[1, 1].set_xticks([12.6, 13.0, 13.4, 13.8])
axes[1, 0].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_xlabel("log M$_{\\rm vir}\\ [h^{-1}\\ M_\\odot]$")
axes[1, 1].set_ylim(-1, 1)

# Average rho_S across mass bins
avg_sat = np.average(artnorm.rho_mat, axis=1)
avg_bol = np.average(bolnorm_rel.rho_mat, axis=1)
avg_smd = np.average(smdnorm_rel.rho_mat, axis=1)

panel_indices = [
    (axes[0, 0], 0),
    (axes[1, 0], 1),
    (axes[0, 1], 2),
    (axes[1, 1], 3)
]

for ax, i in panel_indices:
    avgs = [avg_sat[i], avg_bol[i], avg_smd[i]]

    if i==0:

        for k, (avg, color) in enumerate(zip(avgs, colors)):
            ax.text(
                0.05,
                0.88 - k * 0.09,
                rf"{labels[k]}: $\langle\rho_S\rangle = {avg:.2f}$",
                transform=ax.transAxes,
                color=color,
                fontsize=11
            )

    else:

        for k, (avg, color) in enumerate(zip(avgs, colors)):
            ax.text(
                0.05,
                0.88 - k * 0.09,
                rf"$\langle\rho_S\rangle = {avg:.2f}$",
                transform=ax.transAxes,
                color=color,
                fontsize=11
            )

# Panel labels
axes[0, 0].text(0.9, 0.9, "A", transform=axes[0, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[0, 1].text(0.9, 0.9, "B", transform=axes[0, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 0].text(0.9, 0.9, "C", transform=axes[1, 0].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))
axes[1, 1].text(0.9, 0.9, "D", transform=axes[1, 1].transAxes,
                bbox=dict(boxstyle="round", facecolor="white"))

linestyle_markers = ["*", None]
linestyles = ["-", ":"]
linestyle_handles = [Line2D([0], [0], color="k", ls=ls, lw=1, marker=m)
                      for ls, m in zip(linestyles, linestyle_markers)]
labelz = ["relaxed", "all halos"]
axes[0, 1].legend(linestyle_handles, labelz, loc=[0.45, 0.72],
                   fontsize=11, frameon=True, framealpha=1, handlelength=2)

plt.tight_layout()
plt.savefig("../../figures/relaxed_corrcomp.pdf", bbox_inches="tight")
plt.show()

# %%
np.average(np.abs(artnorm.rho_mat - bolnorm_rel.rho_mat), axis=1).mean()
# Out:
# 0.1758044821246541
