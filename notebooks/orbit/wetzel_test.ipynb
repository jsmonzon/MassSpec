# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
from matplotlib.lines import Line2D
import warnings; warnings.simplefilter('ignore')
import sys
import h5py
import pandas as pd
import seaborn as sns
sys.path.insert(0, '/Users/jsmonzon/Research/SatGen/mcmc/src/')
import jsm_ancillary
import jsm_visualize
import jsm_SHMR
import jsm_mcmc
import jsm_stats
import jsm_models
import jsm_halopull
import evolve as ev
import galhalo as gh
import profiles as profiles
import config as cfg
import init
import aux
from scipy import stats

# %%
early = jsm_visualize.Tree_Vis(file="../../../StellarHalo/data/four_examples/DF/early_evo.npz", merger_crit=-2, fesc=0.2, scatter=False, verbose=False)
hp = early.host_profiles[0]

# %%
sp = early.acc_profiles[14]
sp.Mh
# Out:
# 77793193582.63828

# %%
orb = aux.SatelliteOrbit(hp, z=0, Msub=sp.Mh, sp=sp, model="wetzel2011", N_samples=1000)

# or access distributions directly
plt.hist(orb.get('r_peri_rvir'))
plt.hist(orb.get('circularity_E'))
# Out:
# (array([ 17.,  38.,  65.,  83., 105., 123., 123.,  98.,  90.,  50.]),
#  array([0.05427529, 0.14744022, 0.24060515, 0.33377007, 0.426935  ,
#         0.52009993, 0.61326485, 0.70642978, 0.79959471, 0.89275963,
#         0.98592456]),
#  <BarContainer object of 10 artists>)

# %%
orb = aux.SatelliteOrbit(hp, z=0, Msub=sp.Mh, sp=sp, model="li2020", N_samples=1000)

# or access distributions directly
plt.hist(orb.get('r_peri_rvir'))
plt.hist(orb.get('circularity_E'))
# Out:
# (array([ 39.,  76.,  94., 127., 114., 121., 121., 125.,  85.,  59.]),
#  array([0.01795123, 0.11425914, 0.21056706, 0.30687497, 0.40318288,
#         0.4994908 , 0.59579871, 0.69210662, 0.78841454, 0.88472245,
#         0.98103037]),
#  <BarContainer object of 10 artists>)
